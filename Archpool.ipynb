# %%
def return_arch(idx):
    
    if idx == 0:
        arch = [
            ["input_dimensions", [128, 1, 1]],
            ["ConvT2d", [128, 64*8, 4, 1, 0, False]],
            ["BN2d", [64*8]],
            ["Relu", [True]],
            ["ConvT2d", [64*8, 64*4, 4, 2, 1, False]],
            ["BN2d", [64*4]],
            ["Relu", [True]],
            ["ConvT2d", [64*4, 64*2, 4, 2, 1, False]],
            ["BN2d", [64*2]],
            ["Relu", [True]],
            ["ConvT2d", [64*2, 64, 4, 2, 1, False]],
            ["BN2d", [64]],
            ["Relu", [True]],
            ["ConvT2d", [64, 3, 4, 2, 1, False]],
            ["Tanh", []]
        ]
        
    if idx == 1:
        arch = [
            ["input_dimensions", [3, 64, 64]],
            ["Conv2d", [3, 64, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["Conv2d", [64, 64*2, 4, 2, 1, False]],
            ["BN2d", [64*2]],
            ["LeakyRelu", [0.2, True]],
            ["Conv2d", [64*2, 64*4, 4, 2, 1, False]],
            ["BN2d", [64*4]],
            ["LeakyRelu", [0.2, True]],
            ["Conv2d", [64*4, 64*8, 4, 2, 1, False]],
            ["BN2d", [64*8]],
            ["LeakyRelu", [0.2, True]],
            ["Conv2d", [64*8, 1, 4, 1, 0, False]]
        ]
        
    if idx == 2: # [DCGAN, generator, grayscale, 64x64, wgangp]
        arch = [
            ["input_dimensions", [128, 1, 1]],
            ["ConvT2d", [128, 512, 4, 1, 0, False]],
            ["BN2d", [512]],
            ["Relu", [True]],
            ["ConvT2d", [512, 256, 4, 2, 1, False]],
            ["BN2d", [256]],
            ["Relu", [True]],
            ["ConvT2d", [256, 128, 4, 2, 1, False]],
            ["BN2d", [128]],
            ["Relu", [True]],
            ["ConvT2d", [128, 64, 4, 2, 1, False]],
            ["BN2d", [64]],
            ["Relu", [True]],
            ["ConvT2d", [64, 1, 4, 2, 1, False]],
            ["Tanh", []]
        ]
        
    if idx == 3: # [DCGAN, discriminator, grayscale, 64x64, wgangp]
        arch = [
            ["input_dimensions", [1, 64, 64]],
            ["Conv2d", [1, 64, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["Conv2d", [64, 128, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["Conv2d", [128, 256, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["Conv2d", [256, 512, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["Conv2d", [512, 1, 4, 1, 0, False]]
        ]
        
    if idx == 4: # [Resnet, generator, grayscale, 64x64, wgangp]
        arch = [
            ["input_dimensions", [128, 1, 1]],
            ["ConvT2d", [128, 512, 4, 1, 0, False]],
            ["BN2d", [512]],
            ["Relu", [True]],
            ["ResBlock2d", [512, 256, 3, "zero", "BN2d", False, False, 1.0, "Conv2d"]],
            ["Relu", [True]],
            ["Interpolate", [2, 'nearest']],
            ["ResBlock2d", [256, 128, 3, "zero", "BN2d", False, False, 1.0, "Conv2d"]],
            ["Relu", [True]],
            ["Interpolate", [2, 'nearest']],
            ["ResBlock2d", [128, 64, 3, "zero", "BN2d", False, False, 1.0, "Conv2d"]],
            ["Relu", [True]],
            ["Interpolate", [2, 'nearest']],
            ["ConvT2d", [64, 1, 4, 2, 1, False]],
            ["Tanh", []]
        ]
        
    if idx == 5: # [Resnet, discriminator, grayscale, 64x64, wgangp]
        arch = [
            ["input_dimensions", [1, 64, 64]],
            ["Conv2d", [1, 64, 3, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["ResBlock2d", [64, 128, 3, "zero", "None", False, False, 1.0, "Conv2d"]],
            ["LeakyRelu", [0.2, True]],
            ["AvgPool2d", [3, 2, 1]],
            ["ResBlock2d", [128, 256, 3, "zero", "None", False, False, 1.0, "Conv2d"]],
            ["LeakyRelu", [0.2, True]],
            ["AvgPool2d", [3, 2, 1]],
            ["ResBlock2d", [256, 512, 3, "zero", "None", False, False, 1.0, "Conv2d"]],
            ["LeakyRelu", [0.2, True]],
            ["AvgPool2d", [3, 2, 1]],
            ["Conv2d", [512, 1, 4, 1, 0, False]]
        ]
        
    if idx == 6: # [DCGAN, generator, grayscale, 128x128, wgangp]
        arch = [
            ["input_dimensions", [128, 1, 1]],
            ["ConvT2d", [128, 512, 4, 1, 0, False]],
            ["BN2d", [512]],
            ["Relu", [True]],
            ["ConvT2d", [512, 256, 4, 2, 1, False]],
            ["BN2d", [256]],
            ["Relu", [True]],
            ["ConvT2d", [256, 128, 4, 2, 1, False]],
            ["BN2d", [128]],
            ["Relu", [True]],
            ["ConvT2d", [128, 64, 4, 2, 1, False]],
            ["BN2d", [64]],
            ["Relu", [True]],
            ["ConvT2d", [64, 32, 4, 2, 1, False]],
            ["BN2d", [32]],
            ["Relu", [True]],
            ["ConvT2d", [32, 1, 4, 2, 1, False]],
            ["Tanh", []]
        ]
        
    if idx == 7: # [DCGAN, discriminator, grayscale, 128x128, wgangp]
        arch = [
            ["input_dimensions", [1, 128, 128]],
            ["Conv2d", [1, 32, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["Conv2d", [32, 64, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["Conv2d", [64, 128, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["Conv2d", [128, 256, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["Conv2d", [256, 512, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["Conv2d", [512, 1, 4, 1, 0, False]]
        ]
        
    if idx == 8: # [Resnet, generator, grayscale, 128x128, wgangp]
        arch = [
            ["input_dimensions", [128, 1, 1]],
            ["ConvT2d", [128, 1024, 4, 1, 0, False]],
            ["BN2d", [1024]],
            ["Relu", [True]],
            ["ResBlock2d", [1024, 512, 3, "zero", "BN2d", False, False, 1.0, "Conv2d"]],
            ["Relu", [True]],
            ["Interpolate", [2, 'nearest']],
            ["ResBlock2d", [512, 256, 3, "zero", "BN2d", False, False, 1.0, "Conv2d"]],
            ["Relu", [True]],
            ["Interpolate", [2, 'nearest']],
            ["ResBlock2d", [256, 128, 3, "zero", "BN2d", False, False, 1.0, "Conv2d"]],
            ["Relu", [True]],
            ["Interpolate", [2, 'nearest']],
            ["ResBlock2d", [128, 64, 3, "zero", "BN2d", False, False, 1.0, "Conv2d"]],
            ["Relu", [True]],
            ["Interpolate", [2, 'nearest']],
            ["ConvT2d", [64, 1, 4, 2, 1, False]],
            ["Tanh", []]
        ]
        
    if idx == 9: # [Resnet, discriminator, grayscale, 128x128, wgangp]
        arch = [
            ["input_dimensions", [1, 64, 64]],
            ["Conv2d", [1, 64, 3, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["ResBlock2d", [64, 128, 3, "zero", "None", False, False, 1.0, "Conv2d"]],
            ["LeakyRelu", [0.2, True]],
            ["AvgPool2d", [3, 2, 1]],
            ["ResBlock2d", [128, 256, 3, "zero", "None", False, False, 1.0, "Conv2d"]],
            ["LeakyRelu", [0.2, True]],
            ["AvgPool2d", [3, 2, 1]],
            ["ResBlock2d", [256, 512, 3, "zero", "None", False, False, 1.0, "Conv2d"]],
            ["LeakyRelu", [0.2, True]],
            ["AvgPool2d", [3, 2, 1]],
            ["ResBlock2d", [512, 1024, 3, "zero", "None", False, False, 1.0, "Conv2d"]],
            ["LeakyRelu", [0.2, True]],
            ["AvgPool2d", [3, 2, 1]],
            ["Conv2d", [1024, 1, 4, 1, 0, False]]
        ]
        
    if idx == 10: # [DCGAN, discriminator, grayscale, 64x64, wgangp, spectral_normalization]
        arch = [
            ["input_dimensions", [1, 64, 64]],
            ["SNConv2d", [1, 64, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["SNConv2d", [64, 128, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["SNConv2d", [128, 256, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["SNConv2d", [256, 512, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["SNConv2d", [512, 1, 4, 1, 0, False]]
        ]
        
    if idx == 11: # [Resnet, discriminator, grayscale, 64x64, wgangp, spectral_normalization]
        arch = [
            ["input_dimensions", [1, 64, 64]],
            ["Conv2d", [1, 64, 3, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["ResBlock2d", [64, 128, 3, "zero", "None", False, False, 1.0, "SNConv2d"]],
            ["LeakyRelu", [0.2, True]],
            ["AvgPool2d", [3, 2, 1]],
            ["ResBlock2d", [128, 256, 3, "zero", "None", False, False, 1.0, "SNConv2d"]],
            ["LeakyRelu", [0.2, True]],
            ["AvgPool2d", [3, 2, 1]],
            ["ResBlock2d", [256, 512, 3, "zero", "None", False, False, 1.0, "SNConv2d"]],
            ["LeakyRelu", [0.2, True]],
            ["AvgPool2d", [3, 2, 1]],
            ["Conv2d", [512, 1, 4, 1, 0, False]]
        ]
        
    if idx == 12: # [DCGAN, discriminator, grayscale, 128x128, wgangp, spectral_normalization]
        arch = [
            ["input_dimensions", [1, 128, 128]],
            ["SNConv2d", [1, 32, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["SNConv2d", [32, 64, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["SNConv2d", [64, 128, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["SNConv2d", [128, 256, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["SNConv2d", [256, 512, 4, 2, 1, False]],
            ["LeakyRelu", [0.2, True]],
            ["SNConv2d", [512, 1, 4, 1, 0, False]]
        ]
        
    if idx == 13: # [for 3D CNN testing purpose, classification]
        arch = [
            ["input_dimensions", [16, 16, 16 ,3]],
            ["Conv3d", [3, 32, 3, 1, 0, True]],
            ["LeakyRelu", [0.01, False]],
            ["MaxPool3d", [2, None, 0]],
            ["Conv3d", [32, 64, 3, 1, 0, True]],
            ["LeakyRelu", [0.01, False]],
            ["MaxPool3d", [2, None, 0]],
            ["View", []],
            ["FC", [512, 128, True]],
            ["Relu", [False]],
            ["BN1d", [128]],
            ["Dropout", [0.15]],
            ["FC", [128, 10, True]]
        ]
        
    if idx == 14: # [for 3D CNN classification, topo filled volumes 256 x 256 x 256]
        arch = [
            ["input_dimensions", [256, 256, 256]],
            ["Conv3d", [1, 16, 3, 2, 1, True]],
            ["LeakyRelu", [0.2, True]],
            ["Conv3d", [16, 32, 3, 2, 1, True]],
            ["BN3d", [32]],
            ["LeakyRelu", [0.2, True]],
            ["Conv3d", [32, 64, 3, 2, 1, True]],
            ["BN3d", [64]],
            ["LeakyRelu", [0.2, True]],
            ["Conv3d", [64, 128, 3, 2, 1, True]],
            ["BN3d", [128]],
            ["LeakyRelu", [0.2, True]],
            ["Conv3d", [128, 256, 3, 2, 1, True]],
            ["BN3d", [256]],
            ["LeakyRelu", [0.2, True]],
            ["View", []],
            ["FC", [131072, 128, True]],
            ["Relu", [False]],
            ["BN1d", [128]],
            ["Dropout", [0.15]],
            ["FC", [128, 2, True]]
        ]
        
    if idx == 15: # [for two-stream 3D CNN classificatin, 256 x 256 x 256, part one]
        arch = [
            ["input_dimensions", [256, 256, 256]],
            ["Conv3d", [1, 16, 3, 2, 1, True]],
            ["LeakyRelu", [0.2, True]],
            ["Conv3d", [16, 32, 3, 2, 1, True]],
            ["BN3d", [32]],
            ["LeakyRelu", [0.2, True]],
            ["Conv3d", [32, 64, 3, 2, 1, True]],
            ["BN3d", [64]],
            ["LeakyRelu", [0.2, True]],
            ["Conv3d", [64, 128, 3, 2, 1, True]],
            ["BN3d", [128]],
            ["LeakyRelu", [0.2, True]],
            ["Conv3d", [128, 256, 3, 2, 1, True]],
            ["BN3d", [256]],
            ["LeakyRelu", [0.2, True]],
            ["View", []]
        ]
        
    if idx == 16: # [for two-stream 3D CNN classificatin, 256 x 256 x 256, part two]
        arch = [
            ["input_dimensions", [262144, 1]],
            ["FC", [262144, 256, True]],
            ["Relu", [False]],
            ["BN1d", [256]],
            ["FC", [256, 128, True]],
            ["Relu", [False]],
            ["BN1d", [128]],
            ["Dropout", [0.15]],
            ["FC", [128, 2, True]]
        ]
    #######################################zzl
    if idx == 17:
        arch = [
            ["input_dimensions", [256, 256, 256]],
            ["Conv3d", [1, 16, 3, 2, 1, True]],
            ["LeakyRelu", [0.2, True]],
            ["Conv3d", [16, 32, 3, 2, 1, True]],
            ["BN3d", [32]],
            ["LeakyRelu", [0.2, True]],
            # ["Attention",[3]],                    ########add attention, parameter is the kernel size
            ["Conv3d", [32, 64, 3, 2, 1, True]],
            ["BN3d", [64]],
            ["LeakyRelu", [0.2, True]],
            ["Attention",[3]],                    ########add attention, parameter is the kernel size
            ["Conv3d", [64, 128, 3, 2, 1, True]],
            ["BN3d", [128]],
            ["LeakyRelu", [0.2, True]],
            # ["Attention",[3]],                      ########add attention, parameter is the kernel size
            ["Conv3d", [128, 256, 3, 2, 1, True]],
            ["BN3d", [256]],
            ["LeakyRelu", [0.2, True]],
            ["View", []]
        ]

    if idx == 18:
        arch = [
            ["input_dimensions", [256, 256, 256]],
            ["Conv3d", [1, 16, 3, 2, 1, True]],
            ["LeakyRelu", [0.2, True]],
            ["Conv3d", [16, 32, 3, 2, 1, True]],
            ["BN3d", [32]],
            ["LeakyRelu", [0.2, True]],
            # ["Attention",[3]],                    ########add attention, parameter is the kernel size
            ["Conv3d", [32, 64, 3, 2, 1, True]],
            ["BN3d", [64]],
            ["LeakyRelu", [0.2, True]]
        ]
    
    if idx == 19:
        arch = [
            ["input_dimensions", [32, 32, 32]],
            ["Attention",[3]],                    ########add attention, parameter is the kernel size
            ["Conv3d", [64, 128, 3, 2, 1, True]],
            ["BN3d", [128]],
            ["LeakyRelu", [0.2, True]],
            ["Conv3d", [128, 256, 3, 2, 1, True]],
            ["BN3d", [256]],
            ["LeakyRelu", [0.2, True]],
            ["View", []]
        ]

    if idx == 20:
        arch = [
            ["input_dimensions", [256, 256, 256]],
            ["Conv3d", [1, 16, 3, 2, 1, True]],
            ["LeakyRelu", [0.2, True]],
            ["Attention",[3]],                    ########add attention, parameter is the kernel size
            ["Conv3d", [16, 32, 3, 2, 1, True]],
            ["BN3d", [32]],
            ["LeakyRelu", [0.2, True]],
            ["Attention",[3]],                    ########add attention, parameter is the kernel size
            ["Conv3d", [32, 64, 3, 2, 1, True]],
            ["BN3d", [64]],
            ["LeakyRelu", [0.2, True]],
            ["Attention",[3]],                    ########add attention, parameter is the kernel size
            ["Conv3d", [64, 128, 3, 2, 1, True]],
            ["BN3d", [128]],
            ["LeakyRelu", [0.2, True]],
            ["Attention",[3]],                    ########add attention, parameter is the kernel size
            ["Conv3d", [128, 256, 3, 2, 1, True]],
            ["BN3d", [256]],
            ["LeakyRelu", [0.2, True]],
            ["View", []]
        ]
    
    if idx == 21: # [for one-stream 3D CNN classificatin, 256 x 256 x 256, part two]
        arch = [
            ["input_dimensions", [131072, 1]],
            ["FC", [131072, 256, True]],
            ["Relu", [False]],
            ["BN1d", [256]],
            ["FC", [256, 128, True]],
            ["Relu", [False]],
            ["BN1d", [128]],
            ["Dropout", [0.15]],
            ["FC", [128, 2, True]]
        ]

    if idx == 22: # [add a 256 vector of clinical information]
        arch = [
            ["input_dimensions", [393216, 1]],
            ["FC", [393216, 256, True]],
            ["Relu", [False]],
            ["BN1d", [256]],
            ["FC", [256, 128, True]],
            ["Relu", [False]],
            ["BN1d", [128]],
            ["Dropout", [0.15]],
            ["FC", [128, 2, True]]
        ]

    if idx == 23: # [for one-stream 3D CNN classificatin, 256 x 256 x 256, with clinical] same as idx == 16
        arch = [
            ["input_dimensions", [262144, 1]],
            ["FC", [262144, 256, True]],
            ["Relu", [False]],
            ["BN1d", [256]],
            ["FC", [256, 128, True]],
            ["Relu", [False]],
            ["BN1d", [128]],
            ["Dropout", [0.15]],
            ["FC", [128, 2, True]]
        ] 

    if idx == 24: # [for clinical data]
        arch = [
            ["input_dimensions", [7, 1]],
            ["View", []],
            ["FC", [7, 64, True]],
            ["Relu", [False]],
            ["BN1d", [64]],
            ["FC", [64, 128, True]],
            ["Relu", [False]],
            ["BN1d", [128]],
            ["FC", [128, 256, True]],
            ["Relu", [False]],
            ["BN1d", [256]],
            ["FC", [256, 131072, True]],
            ["View", []]
        ]  

    if idx == 25: # [for only  clinical data]
        arch = [
            ["input_dimensions", [131072, 1]],
            ["FC", [131072, 256, True]],
            ["Relu", [False]],
            ["BN1d", [256]],
            ["FC", [256, 128, True]],
            ["Relu", [False]],
            ["BN1d", [128]],
            ["Dropout", [0.15]],
            ["FC", [128, 2, True]]
        ]   
    #######################################zzl
    return arch

    

def return_general(idx):
    
    general = dict() 
    if idx == 0:
        general = {
            "optimizer":      "Adam",
            "loss":           "focal",       #focal or xentropy
            "reduction":      "mean",          # none' | 'mean' | 'sum'
            "learning_rate":  0.001,
            "beta1":          0.5,
            "beta2":          0.999,
            'gamma':          2.0,
            'alpha':          0.68,        ##0.68 for ispy and 0.4 for private and 0.6 for lung
            'attention':      1,
            'ssl':            False,
            'theta':          0.01  ##0.01 for attention, not use attention change to 0
        }
    return general

def return_advanced_params():
    
    advanced_params = dict()
    advanced_params["wgangp"] = {
        "N_CRITIC":                 5,
        "GP_WEIGHT":                10.0
    }
    advanced_params["persimg"] = {
        "spread":                   1,
        "pixels":                   [64, 64]
    }
    advanced_params["Topo_edge"] = {
        "target_topo_dimension":    1,
        "topology_loss_weight":     0.0005,     # 0.0005 for cremi/isbi
        "use_blind_force":          False,
        "project_2_dim":            0,          # 0 for dim 1; 1 for dim 0
        "image_watershed":          0.0,        # has to be !FLOAT! number
        "target_topo_threshold":    1.0,        # needes to be 0.0 for 0dim
        "number_of_pts_to_fix":     2,
        "hole_test_kernel_radius":  5,
        "hole_test_iteration":      1,
        "hole_test_border_width":   2,
        "hole_test_threshold":      2,
        
        "detect_opposite_2pts":     True,
        "connect_2pts":             True,
        "segment_thickness":        4,
        "pd_subset_rate":           0.81,       # isbi 0.5, cremi 0.1
        "shuffle_subset":           True
    }
    return advanced_params

def return_data_settings(idx):
    
    data_settings = dict()
    if idx == 0:
        data_settings = {
            "epochs":           200,
            "batch_size":       2,
            "batch_workers":    0,
            "shuffle":          True,
            "drop_last":        False,
            'transform':        False,         # True for private
            'binary_mask':      False,
            'extra_aug':        False,
            "datasplit_scheme": "Test",        # options: All|Test|Valid
            "test_split":       0.2,           # obsolete parameter
            "xfold":            10,
            "fold_idx":         0,
            "random_seed":      64
        }
    if idx == 1:
        data_settings = {
            "epochs":           2000,
            "batch_size":       32,
            "batch_workers":    0,
            "shuffle":          True,
            "drop_last":        True,
            "test_split":       0.3,
            "xfold":            10,
            "fold_idx":         3,
            "random_seed":      41
        }
    return data_settings


# def return_settings():
    
#     settings = dict()
#     settings["Basic"] = {
#         "branch_name":       "twostream_adam_fold10-0_batch2_lr0.001_seed64_private_data",         #"map_patch64", cremi_patch64", "isbi_patch64", "retina_patch128"
#         "continue_model":    False, ##False
#         "model_step":        0, ##0
#         "data_extension":    "nii",
#         "dataset":           "nii"
#     }
#     settings["Path"] = {
#         "save_path":         "/home/zhilin/TopoTxR_backup/private_exp_all_new/Pytorch_Log_att_focal_two_private_data",
#         'ori_path':          "/home/zhilin/TopoTxR_backup/private-data/unified_full",     # "/home/zhilin/TopoTxR_backup/data/data_ori", "/home/zhilin/TopoTxR_backup/private-data/MRIs_raw"
#         'extra_path_ori':    "/home/zhilin/TopoTxR_backup/data/extend_ori",
#         'extra_path_dim1':   "/home/zhilin/TopoTxR_backup/data/extend_dim1",
#         'extra_path_dim2':   "/home/zhilin/TopoTxR_backup/data/extend_dim2",
#         "data_path":         "/home/zhilin/TopoTxR_backup/private-data/topo_mask/whole_256_th0.3_dim1_dil0_fv",   #"/home/zhilin/TopoTxR_backup/data/whole_256_th2_dim1_dil0_fv", ##change for ablation
#         "data_path2":        "/home/zhilin/TopoTxR_backup/private-data/topo_mask/whole_256_th0.3_dim2_dil0_fv", #/home/zhilin/TopoTxR_backup/data/whole_256_th2_dim2_dil0_fv", ##change for ablation
#         "pims_path":         "/home/zhilin/TopoTxR_backup/pims",
#         "pds_path":          "/home/zhilin/TopoTxR_backup/pds"
#     }
#     settings["Monitor"] = {
#         "print_step":        2, #16 for ISPY-1, 6 for private
#         "save_step":         2000 # 1000 for ISPY, 50 for private
#     }
#     settings["GPU"] = {
#         "gpu_num":           1,
#         "gpu_enable":        True,
#         "cudnn_benchmark":   True
#     }
#     return settings

# %% [markdown]
# ## lung dataset

# %%
# def return_settings():
    
#     settings = dict()
#     settings["Basic"] = {
#         "branch_name":       "twostream_adam_fold5-4_batch2_lr0.001_seed64_att0.01_focal0.6_lung_data",         #"map_patch64", cremi_patch64", "isbi_patch64", "retina_patch128"
#         "continue_model":    False, ##False
#         "model_step":        0, ##0
#         "data_extension":    "nii",
#         "dataset":           "nii"
#     }
#     settings["Path"] = {
#         "save_path":         "/home/zhilin/TopoTxR_backup/lung/Pytorch_Log_two_lung_data_new",
#         'ori_path':          "/data/zhilin/lung_imagesTs/lung_dataset/ori",     # "/home/zhilin/TopoTxR_backup/data/data_ori", "/home/zhilin/TopoTxR_backup/private-data/MRIs_raw"
#         'extra_path_ori':    "/home/zhilin/TopoTxR_backup/data/extend_ori",
#         'extra_path_dim1':   "/home/zhilin/TopoTxR_backup/data/extend_dim1",
#         'extra_path_dim2':   "/home/zhilin/TopoTxR_backup/data/extend_dim2",
#         "data_path":         "/data/zhilin/lung_imagesTs/lung_dataset/whole_uniformed_th0.3_dim1_dil0_fv",   #"/home/zhilin/TopoTxR_backup/data/whole_256_th2_dim1_dil0_fv", ##change for ablation
#         "data_path2":        "/data/zhilin/lung_imagesTs/lung_dataset/whole_uniformed_th0.3_dim2_dil0_fv", #/home/zhilin/TopoTxR_backup/data/whole_256_th2_dim2_dil0_fv", ##change for ablation
#         "pims_path":         "/home/zhilin/TopoTxR_backup/pims",
#         "pds_path":          "/home/zhilin/TopoTxR_backup/pds"
#     }
#     settings["Monitor"] = {
#         "print_step":        2, #16 for ISPY-1, 6 for private
#         "save_step":         1000 # 1000 for ISPY, 50 for private
#     }
#     settings["GPU"] = {
#         "gpu_num":           1,
#         "gpu_enable":        True,
#         "cudnn_benchmark":   True
#     }
#     return settings

# %%
# def return_settings():
    
#     settings = dict()
#     settings["Basic"] = {
#         "branch_name":       "twostream_adam_fold5-0_batch2_lr0.01_seed77_focal0.4-2_private",         #"map_patch64", cremi_patch64", "isbi_patch64", "retina_patch128"
#         "continue_model":    False, ##False
#         "model_step":        0, ##0
#         "data_extension":    "nii",
#         "dataset":           "nii"
#     }
#     settings["Path"] = {
#         "save_path":         "/home/zhilin/TopoTxR_backup/private_exp/Pytorch_Log_two_focal_private",
#         'ori_path':          "/home/zhilin/TopoTxR_backup/private-data/MRIs_raw",     # "/home/zhilin/TopoTxR_backup/data/data_ori", "/home/zhilin/TopoTxR_backup/private-data/MRIs_raw"
#         'extra_path_ori':    "/home/zhilin/TopoTxR_backup/data/extend_ori",
#         'extra_path_dim1':   "/home/zhilin/TopoTxR_backup/data/extend_dim1",
#         'extra_path_dim2':   "/home/zhilin/TopoTxR_backup/data/extend_dim2",
#         "data_path":         "/home/zhilin/TopoTxR_backup/private-data/topo_mask/whole_256_th0.3_dim1_dil0_fv",   #"/home/zhilin/TopoTxR_backup/data/whole_256_th2_dim1_dil0_fv", ##change for ablation
#         "data_path2":        "/home/zhilin/TopoTxR_backup/private-data/topo_mask/whole_256_th0.3_dim2_dil0_fv", #/home/zhilin/TopoTxR_backup/data/whole_256_th2_dim2_dil0_fv", ##change for ablation
#         "pims_path":         "/home/zhilin/TopoTxR_backup/pims",
#         "pds_path":          "/home/zhilin/TopoTxR_backup/pds"
#     }
#     settings["Monitor"] = {
#         "print_step":        4, #16 for ISPY-1, 4 for private
#         "save_step":         50 # 1000 for ISPY, 200 for private
#     }
#     settings["GPU"] = {
#         "gpu_num":           1,
#         "gpu_enable":        True,
#         "cudnn_benchmark":   True
#     }
#     return settings

# %%
def return_settings():
    
    settings = dict()
    settings["Basic"] = {
        "branch_name":       "twostream_adam_fold10-1_batch2_lr0.01_seed77_att0.1_focal0.68-2",         #"map_patch64", cremi_patch64", "isbi_patch64", "retina_patch128"
        "continue_model":    False, ##False
        "model_step":        0, ##0
        "data_extension":    "nii",
        "dataset":           "nii"
    }
    settings["Path"] = {
        "save_path":         "I:/TopoTxR_backup/vis/Pytorch_Log_two_focal_visual",
        'ori_path':          "I:/TopoTxR_backup/data/data_ori",     # "/home/zhilin/TopoTxR_backup/data/data_ori", "/home/zhilin/TopoTxR_backup/private-data/MRIs_raw"
        'extra_path_ori':    "I:/TopoTxR_backup/data/extend_ori",
        'extra_path_dim1':   "I:/TopoTxR_backup/data/extend_dim1",
        'extra_path_dim2':   "I:/TopoTxR_backup/data/extend_dim2",
        "data_path":         "I:/TopoTxR_backup/data/whole_256_th2_dim1_dil0_fv",   #"/home/zhilin/TopoTxR_backup/data/whole_256_th0.3_dim1_dil0_fv", ##change for ablation
        "data_path2":        "I:/TopoTxR_backup/data/whole_256_th2_dim2_dil0_fv", #"/home/zhilin/TopoTxR_backup/data/whole_256_th0.3_dim2_dil0_fv", ##change for ablation
        "pims_path":         "I:/TopoTxR_backup/pims",
        "pds_path":          "I:/TopoTxR_backup/pds"
    }
    settings["Monitor"] = {
        "print_step":        16, #16 for ISPY-1, 4 for private
        "save_step":         1000 # 1000 for ISPY, 200 for private
    }
    settings["GPU"] = {
        "gpu_num":           1,
        "gpu_enable":        True,
        "cudnn_benchmark":   True
    }
    return settings

# %%
# def return_settings():
    
#     settings = dict()
#     settings["Basic"] = {
#         "branch_name":       "twostream_adam_fold10-9_batch2_lr0.001_seed64_att0.01_focal0.4_private",         #"map_patch64", cremi_patch64", "isbi_patch64", "retina_patch128"
#         "continue_model":    False, ##False
#         "model_step":        0, ##0
#         "data_extension":    "nii",
#         "dataset":           "nii"
#     }
#     settings["Path"] = {
#         "save_path":         "/home/zhilin/TopoTxR_backup/private_exp_test3/Pytorch_Log_two_att_focal_private",
#         'ori_path':          "/home/zhilin/TopoTxR_backup/private-data/training_set/MRIs",     # "/home/zhilin/TopoTxR_backup/data/data_ori", "/home/zhilin/TopoTxR_backup/private-data/MRIs_raw"
#         'extra_path_ori':    "/home/zhilin/TopoTxR_backup/private-data/test_set/MRIs",
#         'extra_path_dim1':   "/home/zhilin/TopoTxR_backup/private-data/test_set/topo_masks/dim1",
#         'extra_path_dim2':   "/home/zhilin/TopoTxR_backup/private-data/test_set/topo_masks/dim2",
#         "data_path":         "/home/zhilin/TopoTxR_backup/private-data/training_set/topo_masks/dim1",   #"/home/zhilin/TopoTxR_backup/data/whole_256_th2_dim1_dil0_fv", ##change for ablation
#         "data_path2":        "/home/zhilin/TopoTxR_backup/private-data/training_set/topo_masks/dim2", #/home/zhilin/TopoTxR_backup/data/whole_256_th2_dim2_dil0_fv", ##change for ablation
#         "pims_path":         "/home/zhilin/TopoTxR_backup/pims",
#         "pds_path":          "/home/zhilin/TopoTxR_backup/pds"
#     }
#     settings["Monitor"] = {
#         "print_step":        4, #16 for ISPY-1, 6 for private
#         "save_step":         2000 # 1000 for ISPY, 50 for private
#     }
#     settings["GPU"] = {
#         "gpu_num":           1,
#         "gpu_enable":        True,
#         "cudnn_benchmark":   True
#     }
#     return settings
