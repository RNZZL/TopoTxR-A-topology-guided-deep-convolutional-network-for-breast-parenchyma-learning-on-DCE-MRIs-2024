# %%
from scipy import stats
import numpy as np

# %%
# # ISPY-1
# # 1. topotxr
# # 2. without focal and tgsa
# # 3. without tgsa
# # 4. without focal
# # 5. self att + focal
# # 6. topotxr+clinical
# # 7. ViT
# # 8. convnext
# # 9. ResNext
# # 10. DenseNet with focal

# #acc
data1 = [0.9375, 0.9375, 0.9375, 0.9375, 0.8750, 0.8750,1, 0.8750, 1, 0.9375]

data2 = [0.9375,0.8125,0.8125,0.8125,0.875,0.75,0.9375,0.75,0.9375,0.9375]

data3 = [0.9375,0.875,0.875,0.875,0.875,0.875,1,0.875,1,0.9375]

data7 = [0.6875,0.8125,0.75,0.8125,0.75,0.6875,0.8125,0.75,0.875,0.7647]

data8 = [0.8125,0.8125,0.75,0.75,0.625,0.75,0.625,0.6875,0.875,0.7647]

data9 = [0.75,0.75,0.6875,0.6875,0.8125,0.6875,0.75,0.8125,0.8125,0.6471]

data10 = [0.6875,0.8125,0.6875,0.6875,0.8125,0.8125,0.8125,0.875,0.875,0.8235]



# #auc
data1_auc = [0.8333,0.9,0.9583,0.9286, 0.8545,0.8667,1, 0.8730, 1, 0.9583]

data2_auc = [0.8333,0.863,0.7917,0.7857,0.8,0.6667,0.75,0.7778,0.9643,0.8333]

data3_auc = [0.9615,0.9091,0.9167,0.8889,0.8545,0.9,1,0.8889,1,0.875]

data7_auc = [0.7167,0.7564,0.8182,0.7,0.5,0.6875,0.7083,0.6667,0.5,0.7045]

data8_auc = [0.75,0.7564,0.7636,0.8182,0.5833,0.75,0.4167,0.625,0.7143,0.7045]

data9_auc = [0.7333,0.4615,0.6091,0.5,0.625,0.6875,0.5833,0.875,0.4643,0.5379]

data10_auc = [0.7167,0.7564,0.5545,0.6091,0.7083,0.8125,0.7917,0.8333,0.7143,0.7879]

# #spe
data1_spe = [0.6667,0.8,1,0.8750,0.8,0.8333,1, 0.8889, 1,1]

data2_spe= [0.6667,1,0.75,0.5714,0.6,0.3333,0.5,0.5556,1,0.6667]

data3_spe = [1,1,1,1,0.8,1,1,0.7778,1,0.75]

data7_spe = [0.8333,0.6667,1,0.4,0,0.875,0.5,0.5,0,0.5]

data8_spe = [0.5,0.6667,0.8,1,0.5,0.75,0,0.5,0.5,0.5]

data9_spe = [0.6667,0,0.4,0,0.25,1,0.25,1,0,0.1667]

data10_spe = [0.8333,0.6667,0.2,0.4,0.5,1,0.75,0.75,0.5,0.6667]

# #sen
data1_sen = [1,1,0.9167,1,0.9091,0.9,1,0.8571, 1,0.9167]

data2_sen= [1,0.7273,0.8333,1,1,1,1,1,0.9286,1]

data3_sen = [0.9231,0.8182,0.8333,0.7778,0.9091,0.8,1,1,1,1]

data7_sen = [0.6,0.8462,0.6364,1,1,0.5,0.9167,0.8333,1,0.9091]

data8_sen = [1,0.8462,0.7273,0.6364,0.6667,0.75,0.8333,0.75,0.9286,0.9091]

data9_sen = [0.8,0.9231,0.8182,1,1,0.375,0.9167,0.75,0.9286,0.9091]

data10_sen = [0.6,0.8462,0.9091,0.8182,0.9167,0.625,0.8333,0.9167,0.9286,0.9091]




data1 = np.array(data1)
data1_auc = np.array(data1_auc)
data1_spe = np.array(data1_spe)
data1_sen = np.array(data1_sen)
data2 = np.array(data2)
data2_auc = np.array(data2_auc)
data2_spe = np.array(data2_spe)
data2_sen = np.array(data2_sen)
data3 = np.array(data3)
data3_auc = np.array(data3_auc)
data3_spe = np.array(data3_spe)
data3_sen = np.array(data3_sen)
data7 = np.array(data7)
data7_auc = np.array(data7_auc)
data7_spe = np.array(data7_spe)
data7_sen = np.array(data7_sen)
data8 = np.array(data8)
data8_auc = np.array(data8_auc)
data8_spe = np.array(data8_spe)
data8_sen = np.array(data8_sen)
data9 = np.array(data9)
data9_auc = np.array(data9_auc)
data9_spe = np.array(data9_spe)
data9_sen = np.array(data9_sen)
data10 = np.array(data10)
data10_auc = np.array(data10_auc)
data10_spe = np.array(data10_spe)
data10_sen = np.array(data10_sen)

print(data1.mean(), data1_auc.mean(), data1_spe.mean(), data1_sen.mean())
print(data2.mean(), data2_auc.mean(), data2_spe.mean(), data2_sen.mean())
print(data3.mean(), data3_auc.mean(), data3_spe.mean(), data3_sen.mean())
print(data7.mean(), data7_auc.mean(), data7_spe.mean(), data7_sen.mean())
print(data8.mean(), data8_auc.mean(), data8_spe.mean(), data8_sen.mean())
print(data9.mean(), data9_auc.mean(), data9_spe.mean(), data9_sen.mean())
print(data10.mean(), data10_auc.mean(), data10_spe.mean(), data10_sen.mean())

print('uncertainty:',np.std(data1,ddof=1)/10)
print('uncertainty:',np.std(data2,ddof=1)/10)
print('uncertainty:',np.std(data7,ddof=1)/10)
print('uncertainty:',np.std(data8,ddof=1)/10)
print('uncertainty:',np.std(data9,ddof=1)/10)
print('uncertainty:',np.std(data10,ddof=1)/10)
###

print(stats.ttest_ind(data1,data2,equal_var=False))
print(stats.ttest_ind(data1_auc,data2_auc,equal_var=False))
print(stats.ttest_ind(data1_spe,data2_spe,equal_var=False))
print(stats.ttest_ind(data1_sen,data2_sen,equal_var=False))
# Out:
# 0.93125 0.9172699999999999 0.8863900000000001 0.9499600000000001
# 0.85625 0.80658 0.66437 0.94892
# 0.9125 0.9194600000000002 0.9327799999999999 0.90615
# 0.77022 0.67583 0.5275000000000001 0.82417
# 0.74522 0.6881999999999999 0.57167 0.8047600000000001
# 0.73971 0.6076900000000001 0.37334 0.84207
# 0.7886 0.7284700000000001 0.62667 0.83029
# uncertainty: 0.0046116549210788865
# uncertainty: 0.007822909731466078
# uncertainty: 0.005895747620107225
# uncertainty: 0.008067861894923312
# uncertainty: 0.006052278634255587
# uncertainty: 0.007385902487547176
# Ttest_indResult(statistic=2.6117145003960447, pvalue=0.01998327885579734)
# Ttest_indResult(statistic=3.5648042897071552, pvalue=0.0023800803764361155)
# Ttest_indResult(statistic=2.9445902745112003, pvalue=0.010699428994419388)
# Ttest_indResult(statistic=0.02992794258506008, pvalue=0.9765332803287661)

# %%
###############################################################
# Rutgers
# 1. topotxr
# 2. without focal and tgsa
# 3. densenet
# 4. ViT
# 5. convnext
# 6. ResNext
# 7. with focal

#acc
data1 = [1,0.9167,1,0.9167,0.9167,0.9167,0.9167,0.9167,0.8333,0.9167]
data2 = [0.9167,0.9167,0.9167,0.75,0.9167,0.9167,0.9167,0.8333,1,0.9167]
data7 = [0.9167,0.8333,1,0.8333,0.9167,0.8333,0.9167,0.9167,0.9167,0.9167]
data3 = [0.9167,0.75,0.8333,0.6667,0.8333,0.8333,0.6667,0.75,0.8333,0.75]
data4 = [0.8333,0.75,0.75,0.8333,0.8333,0.6667,0.75,0.8333,0.9167,0.8333]
data5 = [0.8333,0.8333,0.6667,0.5833,0.75,0.75,0.5833,0.6667,0.9167,0.6667]
data6 = [0.8333,0.8333,0.75,0.75,0.75,0.5833,0.75,0.8333,0.8333,0.6667]

#auc
data1_auc = [1,0.9167,1,0.9167,0.875,0.875,0.9167,0.9375,0.6667,0.9]
data2_auc = [0.875,0.9167,0.9286,0.75,0.875,0.9375,0.9167,0.75,1,0.9286]
data7_auc = [0.9375,0.8333,1,0.8333,0.875,0.75,0.9167,0.875,0.8333,0.9286]
data3_auc = [0.75,0.6111,0.75,0.6667,0.8125,0.8571,0.6667,0.75,0.8333,0.7]
data4_auc = [0.7,0.6111,0.6875,0.8333,0.8125,0.6286,0.75,0.8333,0.9167,0.8]
data5_auc = [0.9,0.7778,0.625,0.5833,0.8125,0.7286,0.5833,0.6667,0.9167,0.6]
data6_auc = [0.7,0.7778,0.75,0.75,0.8125,0.6429,0.75,0.8333,0.8333,0.6]

#spe
data1_spe = [1,0.8333,1,1,1,1,0.8333,0.875,1,0.8]
data2_spe = [1,1,1,1,1,0.875,1,1,1,1]
data7_spe = [0.875,1,1,1,1,1,1,1,1,1]
data3_spe = [1,0.8889,0.5,0.8333,0.875,0.7143,0.6667,0.6667,0.6667,1]
data4_spe = [0.9,0.8889,0.5,0.8333,0.875,0.8571,0.6667,0.6667,1,1]
data5_spe = [0.8,0.8889,0.5,0.8333,0.625,0.8571,0.6667,0.6667,1,1]
data6_spe = [0.9,0.8889,0.75,0.8333,0.625,0.2857,0.6667,1,1,1]

#sen
data1_sen = [1,1,1,0.8333,0.75,0.75,1,1,0.3333,1]
data2_sen = [0.75,0.8333,0.8571,0.5,0.75,1,0.8333,0.5,1,0.8571]
data7_sen = [1,0.6667,1,0.6667,0.75,0.5,0.8333,0.75,0.6667,0.8571]
data3_sen = [0.5,0.3333,1,0.5,0.75,1,0.6667,0.8333,1,0.4]
data4_sen = [0.5,0.3333,0.875,0.8333,0.75,0.4,0.8333,1,0.8333,0.6]
data5_sen = [1,0.6667,0.75,0.3333,1,0.6,0.5,0.6667,0.8333,0.2]
data6_sen = [0.5,0.6667,0.75,0.6667,1,1,0.8333,0.6667,0.6667,0.2]



data1 = np.array(data1)
data1_auc = np.array(data1_auc)
data1_spe = np.array(data1_spe)
data1_sen = np.array(data1_sen)
data5 = np.array(data5)
data5_auc = np.array(data5_auc)
data5_spe = np.array(data5_spe)
data5_sen = np.array(data5_sen)

print(data1.mean(), data1_auc.mean(), data1_spe.mean(), data1_sen.mean())
print(data5.mean(), data5_auc.mean(), data5_spe.mean(), data5_sen.mean())


###
print('uncertainty:',np.std(data1,ddof=1)/10)
print('uncertainty:',np.std(data2,ddof=1)/10)
print('uncertainty:',np.std(data3,ddof=1)/10)
print('uncertainty:',np.std(data4,ddof=1)/10)
print('uncertainty:',np.std(data5,ddof=1)/10)
print('uncertainty:',np.std(data6,ddof=1)/10)
###

print(stats.ttest_ind(data1,data6,equal_var=False))
print(stats.ttest_ind(data1_auc,data6_auc,equal_var=False))
print(stats.ttest_ind(data1_spe,data6_spe,equal_var=False))
print(stats.ttest_ind(data1_sen,data6_sen,equal_var=False))
# Out:
# 0.92502 0.9004300000000001 0.93416 0.8666599999999999
# 0.7249999999999999 0.71939 0.78377 0.655
# uncertainty: 0.004730646655350384
# uncertainty: 0.006574455279505839
# uncertainty: 0.008049385138699175
# uncertainty: 0.007026317907220919
# uncertainty: 0.011146056602125155
# uncertainty: 0.00828593963021428
# Ttest_indResult(statistic=5.524964113868937, pvalue=6.921493685298068e-05)
# Ttest_indResult(statistic=4.048408368031515, pvalue=0.0007952036472573481)
# Ttest_indResult(statistic=1.8277677090025857, pvalue=0.09333354523105532)
# Ttest_indResult(statistic=1.7033612873046666, pvalue=0.1058190947354961)

# %% [markdown]
# ## lung

# %%
# 1. topotxr (shuffle)
# 2. without focal and tgsa (shuffle)
# 3. densenet
# 4. ViT
# 5. convnext
# 6. ResNext
# 7. topotxr (no shuffle)
# 8. without focal and tgsa (no suffle)

#acc
data1 = [0.9333,0.8667,0.9333,0.8667,0.8947]
data2 = [0.8,0.8667,0.8667,0.9333,0.8421]
data3 = [0.6667,0.5333,0.7333,0.8667,0.8947]
data4 = [0.7333,0.6,0.7333,0.9333,0.7895]
data5 = [0.6667,0.6,0.8,0.9333,0.7895]
data6 =[0.7333,0.6,0.9333,0.7333,0.7895]
data7 = [0.875,0.875,0.875,0.9375,0.9333]
data8 = [0.75,0.875,0.8125,0.9375,0.8]

#auc
data1_auc = [0.9375,0.8889,0.95,0.9,0.875]
data2_auc = [0.7857,0.8889,0.9,0.95,0.8295]
data3_auc = [0.7,0.5179,0.7232,0.85,0.892]
data4_auc = [0.65,0.5982,0.7411,0.95,0.8011]
data5_auc = [0.65,0.6071,0.8036,0.95,0.7841]
data6_auc = [0.75,0.6161,0.95,0.7411,0.8011]
data7_auc = [0.873,0.9091,0.8889,0.9615,0.9286]
data8_auc = [0.7778,0.8545,0.8016,0.9615,0.8125]

#spe
data1_spe = [0.875,1,1,1,0.75]
data2_spe = [1,1,1,1,0.75]
data3_spe = [0.8,0.75,0.5714,0.8,0.875]
data4_spe = [0.4,0.625,0.8571,1,0.875]
data5_spe = [0.6,0.5,0.8571,1,0.75]
data6_spe = [0.8,0.375,1,0.8571,0.875]
data7_spe = [0.8889,1,1,1,1]
data8_spe = [0.5556,0.8,0.7143,1,0.625]

#sen
data1_sen = [1,0.7778,0.9,0.8,1]
data2_sen = [0.5714,0.7778,0.8,0.9,0.9091]
data3_sen = [0.6,0.2857,0.875,0.9,0.9091]
data4_sen = [0.9,0.5714,0.625,0.9,0.7273]
data5_sen = [0.7,0.7143,0.75,0.9,0.8182]
data6_sen = [0.7,0.8571,0.9,0.625,0.7273]
data7_sen = [0.8571,0.8182,0.7778,0.9231,0.8571]
data8_sen = [1,0.9091,0.8889,0.9231,1]



data1 = np.array(data1)
data1_auc = np.array(data1_auc)
data1_spe = np.array(data1_spe)
data1_sen = np.array(data1_sen)
data2 = np.array(data2)
data2_auc = np.array(data2_auc)
data2_spe = np.array(data2_spe)
data2_sen = np.array(data2_sen)

print(data1.mean(), data1_auc.mean(), data1_spe.mean(), data1_sen.mean())
print(data2.mean(), data2_auc.mean(), data2_spe.mean(), data2_sen.mean())

###
###
print('uncertainty:',np.std(data1,ddof=1)/5)
print('uncertainty:',np.std(data2,ddof=1)/5)
print('uncertainty:',np.std(data3,ddof=1)/5)
print('uncertainty:',np.std(data4,ddof=1)/5)
print('uncertainty:',np.std(data5,ddof=1)/5)
print('uncertainty:',np.std(data6,ddof=1)/5)
###
###

print(stats.ttest_ind(data1,data2,equal_var=False))
print(stats.ttest_ind(data1_auc,data2_auc,equal_var=False))
print(stats.ttest_ind(data1_spe,data2_spe,equal_var=False))
print(stats.ttest_ind(data1_sen,data2_sen,equal_var=False))
# Out:
# 0.89894 0.9102799999999999 0.925 0.89556
# 0.8617600000000001 0.8708199999999999 0.95 0.79166
# uncertainty: 0.006676849556489946
# uncertainty: 0.00967863213475954
# uncertainty: 0.034505322487987274
# uncertainty: 0.02406375864240664
# uncertainty: 0.025842983573883267
# uncertainty: 0.02406375864240664
# Ttest_indResult(statistic=1.4141061545170865, pvalue=0.19962492564586412)
# Ttest_indResult(statistic=1.231722788909479, pvalue=0.264930352102485)
# Ttest_indResult(statistic=-0.3535533905932725, pvalue=0.7328098736023427)
# Ttest_indResult(statistic=1.346175114693502, pvalue=0.21731943397850095)
