# %%
# %run Archpool.ipynb
# %run Argparser.ipynb
# %run FileIO.ipynb
# %run CNN.ipynb
# %run Clinical.ipynb
####### Net.ipynb for focal loss and Data.ipynb for augmentation
import torch
torch.set_num_threads(4)
torch.cuda.set_device(3)

settings    = return_settings()
parser      = Argparser(settings)
general     = return_general(0)
arch1       = return_arch(24)
arch2       = return_arch(25)
data_params = return_data_settings(0)

print(settings['Basic']['branch_name'])
print(data_params)

mlp = CLINICAL(general, [arch1, arch2])
mlp.train(data_params)
# Out:
# twostream_adam_fold10-0_batch2_lr0.001_seed64_focal0.68_clinical
# {'epochs': 500, 'batch_size': 2, 'batch_workers': 0, 'shuffle': True, 'drop_last': False, 'transform': False, 'binary_mask': False, 'extra_aug': False, 'datasplit_scheme': 'Test', 'test_split': 0.2, 'xfold': 10, 'fold_idx': 0, 'random_seed': 64}
# initialize network with normal
# initialize network with normal
# 0 :
# ISPY_1001_0_TDA.npy
# 0
# 1 :
# ISPY_1002_0_TDA.npy
# 0
# 2 :
# ISPY_1003_0_TDA.npy
# 0
# 3 :
# ISPY_1004_0_TDA.npy
# 0
# 4 :
# ISPY_1005_0_TDA.npy
# 0
# 5 :
# ISPY_1007_0_TDA.npy
# 0
# 6 :
# ISPY_1008_0_TDA.npy
# 0
# 7 :
# ISPY_1009_0_TDA.npy
# 0
# 8 :
# ISPY_1010_1_TDA.npy
# 1
# 9 :
# ISPY_1011_1_TDA.npy
# 1
# 10 :
# ISPY_1012_0_TDA.npy
# 0
# 11 :
# ISPY_1013_0_TDA.npy
# 0
# 12 :
# ISPY_1015_1_TDA.npy
# 1
# 13 :
# ISPY_1016_0_TDA.npy
# 0
# 14 :
# ISPY_1017_0_TDA.npy
# 0
# 15 :
# ISPY_1021_1_TDA.npy
# 1
# 16 :
# ISPY_1027_0_TDA.npy
# 0
# 17 :
# ISPY_1029_0_TDA.npy
# 0
# 18 :
# ISPY_1030_1_TDA.npy
# 1
# ...
